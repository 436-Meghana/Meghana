# %% [markdown]
# <a href="https://colab.research.google.com/github/436-Meghana/Meghana/blob/main/NLP_EXP_NO_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install textblob nltk transformers

# %%
from textblob import TextBlob

# Sample tweets
tweets = [
    "I love this product! It's amazing ",
    "This is the worst service ever ",
    "The experience was okay, nothing special."
]

print("Sentiment Analysis Results:\n")

for tweet in tweets:
    analysis = TextBlob(tweet)
    polarity = analysis.sentiment.polarity

    if polarity > 0:
        sentiment = "Positive"
    elif polarity < 0:
        sentiment = "Negative"
    else:
        sentiment = "Neutral"

    print(f"Tweet: {tweet}")
    print(f"Polarity: {polarity}")
    print(f"Sentiment: {sentiment}\n")
# Out:
# Sentiment Analysis Results:
#
# Tweet: I love this product! It's amazing
# Polarity: 0.6125
# Sentiment: Positive
#
# Tweet: This is the worst service ever
# Polarity: -1.0
# Sentiment: Negative
#
# Tweet: The experience was okay, nothing special.
# Polarity: 0.4285714285714286
# Sentiment: Positive

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("sshleifer/distilbart-cnn-12-6")
model = AutoModelForSeq2SeqLM.from_pretrained("sshleifer/distilbart-cnn-12-6")

# Sample long text
text = """
Artificial Intelligence is transforming industries by enabling machines to learn from data.
It is widely used in healthcare, finance, education, and more.
AI helps in automation, decision-making, and improving efficiency.
However, it also raises concerns about privacy and job displacement.
"""

# Tokenize the input text
inputs = tokenizer([text], max_length=1024, return_tensors="pt", truncation=True)

# Generate summary
summary_ids = model.generate(inputs["input_ids"], num_beams=4, max_length=50, min_length=20, early_stopping=True)

# Decode the generated summary
summary_text = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summary_ids]

print("Original Text:\n", text)
print("\nSummary:\n", summary_text[0])
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Please make sure the generation config includes `forced_bos_token_id=0`.
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/358 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# ...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

nltk.download('vader_lexicon')

analyzer = SentimentIntensityAnalyzer()

tweet = "I love the new update, it's awesome!"

score = analyzer.polarity_scores(tweet)

print("Tweet:", tweet)
print("Scores:", score)

if score['compound'] >= 0.05:
    print("Sentiment: Positive")
elif score['compound'] <= -0.05:
    print("Sentiment: Negative")
else:
    print("Sentiment: Neutral")
# Out:
# Tweet: I love the new update, it's awesome!
# Scores: {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.8622}
# Sentiment: Positive
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
