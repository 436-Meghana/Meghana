# %% [markdown]
# <a href="https://colab.research.google.com/github/436-Meghana/Meghana/blob/main/NLP_EXP_NO_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re

# %%
data_out = pd.read_csv('/content/twitter4000.csv')

# %%
pattern = r'\w+@\w+.\w+'
pattern = r'\b\b'

# %%
data_out['email'] = data_out['twitts'].apply(lambda x: re.findall(pattern=pattern, string=x))
data_out['email'].sample(5)
# Out:
# 848     []
# 2425    []
# 556     []
# 154     []
# 3213    []
# Name: email, dtype: object

# %%
data_out['twitts'].apply(lambda x: re.findall(pattern=pattern, string=x))
# Out:
# 0                [, , , , , , , , , , , , , , , , , , , ]
# 1                            [, , , , , , , , , , , , , ]
# 2       [, , , , , , , , , , , , , , , , , , , , , , ,...
# 3                                [, , , , , , , , , , , ]
# 4       [, , , , , , , , , , , , , , , , , , , , , , ,...
#                               ...
# 3995                                         [, , , , , ]
# 3996                     [, , , , , , , , , , , , , , , ]
# 3997                                 [, , , , , , , , , ]
# 3998             [, , , , , , , , , , , , , , , , , , , ]
# 3999    [, , , , , , , , , , , , , , , , , , , , , , ,...
# Name: twitts, Length: 4000, dtype: object

# %%
pattern = r'httos\S+|www\S+'

# %%
data_int = pd.read_csv('/content/twitter4000.csv')

# %%
pattern = r'/b[A-Za-z0-9,_%+-]+@[A-ZA-Za-z0-9,-]+\.[A-Z|a-z]{2,}\b'

# %%
data_out['email']
# Out:
# 0       []
# 1       []
# 2       []
# 3       []
# 4       []
#         ..
# 3995    []
# 3996    []
# 3997    []
# 3998    []
# 3999    []
# Name: email, Length: 4000, dtype: object

# %%
data_out['email'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       []
# 1       []
# 2       []
# 3       []
# 4       []
#         ..
# 3995    []
# 3996    []
# 3997    []
# 3998    []
# 3999    []
# Name: email, Length: 4000, dtype: object>

# %%
data_int
# Out:
#                                                  twitts  sentiment
# 0     is bored and wants to watch a movie  any sugge...          0
# 1              back in miami.  waiting to unboard ship           0
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                     ughhh i am so tired  blahhhhhhhhh          0
# 4     @mandagoforth me bad! It's funny though. Zacha...          0
# ...                                                 ...        ...
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1
#
# [4000 rows x 2 columns]

# %%
data_int.head()
# Out:
#                                               twitts  sentiment
# 0  is bored and wants to watch a movie  any sugge...          0
# 1           back in miami.  waiting to unboard ship           0
# 2  @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                  ughhh i am so tired  blahhhhhhhhh          0
# 4  @mandagoforth me bad! It's funny though. Zacha...          0

# %%
# !pip install data
# Out:
# ERROR: Could not find a version that satisfies the requirement data_out (from versions: none)
# ERROR: No matching distribution found for data_out

# %%
data_out['twitts'].apply(lambda x: re.findall(pattern=pattern, string=x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3724511325.py in <cell line: 0>()
# ----> 1 data_out['twitts'].apply(lambda x: re.findall(pattern=pattern, string=x))
#
# NameError: name 'data_out' is not defined

# %%
#For removing URLs
pattern = r'http\S+|www\S+'
data_out['twitts'].apply(lambda x: re.findall(pattern=pattern, string=x))
