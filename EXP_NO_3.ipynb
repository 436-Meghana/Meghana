# %% [markdown]
# <a href="https://colab.research.google.com/github/436-Meghana/Meghana/blob/main/EXP_NO_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c6c1898b-69d1-4ade-b038-62257ce4a0c8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6c1898b-69d1-4ade-b038-62257ce4a0c8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('/content/twitter4000.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   twitts     4000 non-null   object
#  1   sentiment  4000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 62.6+ KB

# %%
data.count()
# Out:
# twitts       4000
# sentiment    4000
# dtype: int64

# %%
data['sentiment'].value_counts()
# Out:
# sentiment
# 0    2000
# 1    2000
# Name: count, dtype: int64

# %%
data.head()
# Out:
#                                               twitts  sentiment
# 0  is bored and wants to watch a movie  any sugge...          0
# 1           back in miami.  waiting to unboard ship           0
# 2  @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                  ughhh i am so tired  blahhhhhhhhh          0
# 4  @mandagoforth me bad! It's funny though. Zacha...          0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
pattern = r'\s'
data['twitts'].apply(lambda x: re.sub(pattern, '', x))
# Out:
# 0             isboredandwantstowatchamovieanysuggestions?
# 1                        backinmiami.waitingtounboardship
# 2       @misskpeyawwwwdntdisbrngbakmemoriessss,IthnkI'...
# 3                             ughhhiamsotiredblahhhhhhhhh
# 4       @mandagoforthmebad!It'sfunnythough.ZacharyQuin...
#                               ...
# 3995                                       ijustgraduated
# 3996                     Templatingworks;itallhastobedone
# 3997                          mommyjustbroughtmestarbucks
# 3998        @omareppswatchingyouonaHousere-run...lovinit.
# 3999    ThanksfortryingtomakemesmileI'llmakeyour18thsp...
# Name: twitts, Length: 4000, dtype: object

# %%
pattern = r'\s'
data['char_count']=data['twitts'].apply(lambda x: len(re.sub(pattern,'',x)))

# %%
data
# Out:
#                                                  twitts  sentiment
# 0     is bored and wants to watch a movie  any sugge...          0
# 1              back in miami.  waiting to unboard ship           0
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                     ughhh i am so tired  blahhhhhhhhh          0
# 4     @mandagoforth me bad! It's funny though. Zacha...          0
# ...                                                 ...        ...
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1
#
# [4000 rows x 2 columns]
