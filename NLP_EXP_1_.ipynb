# %% [markdown]
# <a href="https://colab.research.google.com/github/436-Meghana/Meghana/blob/main/NLP_EXP_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
input ="Hi I am Meghana. How are you "
output1 = word_tokenize( input)
print(output1)
# Out:
# ['Hi', 'I', 'am', 'Meghana', '.', 'How', 'are', 'you']

# %%
input ="Hi I am Meghana. How are you "
output1 = sent_tokenize( input)
print(output1)
# Out:
# ['Hi I am Meghana.', 'How are you']

# %%
input ="I am stduying at Alliance University. I'm a Third year student"
output2 = sent_tokenize( input)
print(output2)
# Out:
# ['I am stduying at Alliance University.', "I'm a Third year student"]

# %%
# !pip install -U spacy

# %%
# !python -m download en_core_web_sm
# Out:
# /usr/bin/python3: No module named download

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
input = "This is the second session"
doc = nlp(input)

# %%
for token in doc:
  print(token)
# Out:
# This
# is
# the
# second
# session

# %%
for sent in doc.sents:
  print(sent)
# Out:
# This is the second session

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
import en_core_web_sm
nlp = en_core_web_sm.load()
doc = nlp("This is a sentence.")
print([(w.text, w.pos_) for w in doc])
# Out:
# [('This', 'PRON'), ('is', 'AUX'), ('a', 'DET'), ('sentence', 'NOUN'), ('.', 'PUNCT')]

# %%
- lexemes = [nlp.vocab[orth] for orth in nlp.vocab.vectors]
+ lexemes = [nlp.vocab[word] for word in external_word_list]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1777546760.py in <cell line: 0>()
#       1 lexemes = [nlp.vocab[orth] for orth in nlp.vocab.vectors]
# ----> 2 lexemes = [nlp.vocab[word] for word in external_word_list]
#
# NameError: name 'external_word_list' is not defined
